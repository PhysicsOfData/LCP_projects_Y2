# %% [markdown]
# # High Level Programming Project
# ## Local PageRank - Local similarities in the nodes of a network
# ##### Francesco Barbato<sup>1</sup>, Mario Serafin<sup>1</sup>, Tommaso Boccato<sup>1</sup>, Valentina Rossi<sup>1</sup>
# ### <sup>1</sup>Università degli Studi di Padova

# %% [markdown]
# ## Introduction
# Clustering is a well-studied Computer Science task which belongs to the unsupervised learning paradigm of Machine Learning. In general, this technique can be used to partition various types of data. Amongst the many applications, the most widely used comprize image segmentation, statistical analysis and community detection in social networks.<br>
# In this project, we use it to extract communities in a network, allowing the clustering algorithm to make use of its weights. In particular, we exploited personalized PageRank™ to generate new weights for the network in order to better describe the nodes similarity, starting from the original ones provided within the dataset.<br>
# A novel approach towards this goal was the choice of keeping only the ranking information related to the nodes’ neighbourhoods, effectively generating a personalized PageRank™ matrix which has the same shape of the adjacency one, being the sparseness propriety preserved.<br>
# To better exploit the generated weights, we designed several ad-hoc clustering algorithms and then compared their performances.

# %%
# import general use libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import networkx as nx

# silence matplotlib warnings
import warnings
warnings.filterwarnings('ignore')

# import developed libraries
from libs.cython.pyx.edgelistParser import edgelistParser
from libs.python.plotNetwork import plotNetworkClusters
from libs.cython.pyx.utils import (
    list2matrix,
    transposeEdgelist
)
from libs.cython.cpp.pageRankCpp import (
    cppGetDegree,
    cppLocalPageRank_weight as localPageRank_weight,
    cppApproximateSimrank as approximateSimrank,
    cppLocalPageRank as localPageRank
)
from libs.python.clustering import (
    build_network,
    cluster1,
    cluster2,
    cluster3,
    cluster4
)

# %% [markdown]
# ## Local PageRank
# Search engines have become fundamental in exploring the web and discovering information. A good performing engine is both fast and guarantees high correlation between the produced results and the inputted terms.<br>
# Such requirements can be satisfied by PageRank™, an algorithm originally proposed by Google, which quantifies and ranks the importance of each webpage with respect to the pages connected to it.
# Even if originally developed to explore the internet, PageRank™ can be easily generalized for any kind of networks: web pages become nodes and link to other pages become edges.<br>
# In short, the underlying idea is that links from an important page, i.e. edges from a hub, make the page, or node, more important. The ranking of a node, in fact, is based on the number of edges the node has, and the importance of the other node of the same edge. Mathematically speaking, the problem could be formulated in terms of search of the eigenvectors associated to the largest eigenvalues of a stochastic matrix associated with the web structure (i.e. Adjacency Matrix).<br>
# Various approaches have been shown in literature for the implementation of the PageRank™ algorithm, but one of the most common ones is local PageRank™ with randomized walk.
# ### Formal Definition
# Starting from the definition of local PageRank™ through a lazy random walk, provided in paper [[1](http://www.leonidzhukov.net/hse/2015/networks/papers/andersen06localgraph.pdf)], we define an iterative process which consists of a series of operations, called push operations, which update two distribution vectors, $p$ and $r$, the approximate PageRank™ vector and the residual error respectively. For each node, we initialize $p$ as an all zeros vector and $r$ as a vector with the element at the index corresponding to the node onto which PageRank™ is called set to one, and the rest set to zero. Both have length equal to the number of nodes in the network, namely, the dimensions of the adjacency matrix, square by construction.<br>
# These vectors are then updated using the aforementioned push operation, that is the core of this algorithm.<br>
# First, we compute the new values for $p$ and $r$ as:
# $$
# \begin{align}
# p’[u] &= p[u] + \alpha r[u]\\
# r’[u] &= r[u]\frac{1-\alpha}{2}
# \end{align}
# $$
# where $u$ is the starting node. Then, since we are updating $r$ for that node, each of its neighbours needs to be updated accordingly. In order to keep track of what needs to be updated, the next nodes to be processed are put in a priority queue.
# ### Complexity Analysis
# This implementation of approximate PageRank™ is reported to run in $O\left(\frac{\log n}{\epsilon\alpha}\right)$, as it was shown in [[1](http://www.leonidzhukov.net/hse/2015/networks/papers/andersen06localgraph.pdf)]. Since, in the worst case, it must be done for each node in the network, the overall complexity of local PageRank™ results to be $O\left(n\frac{\log n}{\epsilon\alpha}\right)$.<br>
# Overall, local PageRank™ still allows for a faster implementation, since it has been shown in [[2](https://dl.acm.org/doi/pdf/10.1145/3210377.3210409?download=true)] that, even by using distributed algorithms over all the network, the complexity of computing the PageRank™ of all nodes in a graph is around $O\left(\frac{n}{k^2}\right)$, with $k$ the number of machines available for the analysis. Local PageRank™, thus, computes the scores proportionally to the logarithm of the number of the nodes in the network, as opposed of being linear in said number.

# %%
# load a dataset, in both weighted and unweighted forms
# this dataset can be found in https://snap.stanford.edu/data/ego-Facebook.html
A_weighted, N, original_idxs = edgelistParser("data/datasets/facebook/0.edges", "raw_list", True)
A, _, _ = edgelistParser("data/datasets/facebook/0.edges", "raw_list", False)

# %%
# test performance on both verions
print("Weighted version:")
# %timeit localPageRank_weight(A_weighted, c=0.85, return_only_neighbours=True)
print("Unweighted version:")
# %timeit localPageRank(A, c=0.85, return_only_neighbours=True)
# Out:
# Weighted version:
# 91.8 ms ± 232 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Unweighted version:
# 91.7 ms ± 242 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# generate the L matrix, assuming both weighted and unweighted input
L_weighted = localPageRank_weight(A_weighted, c=0.85, return_only_neighbours=True)
L = localPageRank(A, c=0.85, return_only_neighbours=True)

# convert to numpy matrix, to visually check the results
L_weighted_mat = list2matrix(L_weighted)
L_mat = list2matrix(L)

# plot the matrices' spy 
fig, axs = plt.subplots(1, 2, figsize=(14, 6))
fig.subplots_adjust(wspace=.001)
axs[0].spy(L_weighted_mat)
axs[0].set_title("Weighted Local PageRank Matrix Spy")
axs[0].set_xlabel("Node ID")
axs[0].set_ylabel("Node ID")
axs[1].spy(L_mat)
axs[1].set_title("Unweighted Local PageRank Matrix Spy")
axs[1].set_xlabel("Node ID")
axs[1].set_ylabel("Node ID", rotation=-90, labelpad=15)
axs[1].yaxis.set_label_position("right")
axs[1].yaxis.tick_right()

# %%
# and print the difference to check that the same result was obtained
print("Difference between Local PageRank Computations:", np.linalg.norm(L_mat-L_weighted_mat), "\n\n\n")
# Out:
# Difference between Local PageRank Computations: 0.0

# %% [markdown]
# At this stage, we verify that the algorithm correctly solves the problem of computing an approximation of the Lazy PageRank™ score:
# $$
# \begin{equation}
# \mathbb{pr}(\alpha, \vec{s}) = \alpha\vec{s} + (1-\alpha)\mathbb{pr}(\alpha, \vec{s})W
# \end{equation}
# $$
# Where matrix $W$ is defined as follows:
# $$
# \begin{equation}
# W = \frac{1}{2}\left(I + D^{-1}A \right)
# \end{equation}
# $$
# with $D$, the diagonal matrix that collects the nodes degree on its diagonal: $D = A\vec{\mathbb{1}}$.<br>
# Moreover we say that a vector $\vec{p}$ (with it's residuals $\vec{r}$), computed by the algorithm, is an approximation of the solution if:
# $$
# \begin{equation}
# \vec{p} + \mathbb{pr}(\alpha, \vec{r}) = \mathbb{pr}(\alpha, \vec{s})
# \end{equation}
# $$

# %%
# define all-in-one function to compute the infinite precision lazy PageRank
def page_rank(A, A_mat, N, s, alpha):
    s = s.reshape(1, N)
    I = np.eye(N)
    d_inv = np.zeros(N)
    for i in range(N):
        d_inv[i] = len(A[i])**(- 1)
    D_inv = np.diag(d_inv)
    W = 1/2*(I + np.dot(D_inv, A_mat))
    p = alpha*np.dot(s, np.linalg.inv(I - (1 - alpha)*W))
    return p.reshape(N)

# %%
# load network for algorithm verification, use unweighted version
# This dataset can be found in https://snap.stanford.edu/data/ego-Facebook.html
A, N, original_idxs = edgelistParser("data/datasets/facebook/686.edges", "raw_list", False)
A_mat = list2matrix(A, False)
print("Loaded Network's node number N =", N)
# Out:
# Loaded Network's node number N = 168

# %%
# plot the loaded dataset
g = nx.Graph(A_mat)
fig = plt.figure(figsize=(14, 14))
nx.draw_networkx(g, node_size=10, with_labels=False, node_color="#51B9C2", edge_color="#505050")
ax = fig.get_axes()[0]
ax.axis('off')
ax.set_title("Ego-Facebook's '686.edges' Network")
fig.show()

# %%
# set the PageRank parameters
v = 0
alpha = 0.15
epsilon = 1e-20

# %%
# compute PageRank
s = np.zeros((1, N))
s[0,v] = 1

# using infinite precision
pr = page_rank(A, A_mat, N, s, alpha)
# and the approximate version
p, r = approximateSimrank(A, v, alpha, epsilon, return_only_neighbours=False)

# %%
# plot the results
f = plt.figure(figsize=(14, 14))
# create major subplots
gs0 = gridspec.GridSpec(2, 1, figure=f)
# further split the second row
gs00 = gridspec.GridSpecFromSubplotSpec(1, 2, subplot_spec=gs0[1], wspace=0.05)

# apply the separation to the figure
ax1 = f.add_subplot(gs0[0])
ax2 = f.add_subplot(gs00[0])
ax3 = f.add_subplot(gs00[1])

# plot the linear scale result, across the top
ax1.plot(p, "x")
ax1.plot(pr, ".")
ax1.legend(["approximate", "real"])
ax1.set_title("Linear y-scale PageRank Output")
ax1.set_xlim([-1, N])
ax1.set_xlabel("Node ID")
ax1.set_ylabel("Rank, $\\mathbb{pr}(\\alpha, \\vec{s})$")
ax1.grid(True)

# plot the log scale result, bottom left square plot
ax2.plot(p, "x")
ax2.plot(pr, ".")
ax2.legend(["approximate", "real"])
ax2.set_title("Logarithminc y-scale PageRank Output")
ax2.set_xlim([-1, N])
ax2.set_xlabel("Node ID")
ax2.set_ylabel("Rank, $\\mathbb{pr}(\\alpha, \\vec{s})$")
ax2.set_yscale("log")
ax2.grid(True)

# check correctness
x = np.linspace(np.min(pr), np.max(pr))
y = 1/2*x

# plot the correctness QQ-Plot, bottom right square plot
ax3.loglog(pr, p + page_rank(A, A_mat, N, np.array(r), alpha), ".")
ax3.loglog(x,y)
ax3.set_title("Correctness QQ-Plot")
ax3.set_xlabel("True Rank, $\\mathbb{pr}(\\alpha, \\vec{s})$")
ax3.set_ylabel("Approximated Rank plus Residuals Rank, $\\vec{p} + \\mathbb{pr}(\\alpha, \\vec{r})$", rotation=-90, labelpad=15)
ax3.yaxis.set_label_position("right")
ax3.yaxis.tick_right()
ax3.grid(True, which="both", ls="--")

# %%
# dataset names
names = ["Aggregation", "R15", "D31"]

# load, build and plot the networks
datasets = {}

# create the figure for the plot
f = plt.figure(figsize=(14, 21))

# create major subplots
gs0 = gridspec.GridSpec(3, 1, figure=f)

# further split the second row
gs00 = [gridspec.GridSpecFromSubplotSpec(1, 2, subplot_spec=gs, wspace=0.05) for gs in gs0]

# iterate over the datasets
for i, name in enumerate(names):
    # build the network
    A, positions, clusters = build_network("data/datasets/" + name + ".txt", radius=3.5)
    A_mat = list2matrix(A, False)
    
    # generate the L matrix
    L = localPageRank(A, c=0.85, epsilon=1e-8, max_iters=200, return_only_neighbours=True)
    
    # store network data
    datasets[name] = {
        "A_mat": A_mat,
        "positions": positions,
        "clusters": clusters,
        "L": L,
        "L_T": transposeEdgelist(L, True)
    }
    
    # spy the matrices
    ax0 = f.add_subplot(gs0[i])
    ax0.set_title("Network: "+names[i], pad=18, fontweight="bold")
    ax0.axis("off")
    ax00 = f.add_subplot(gs00[i][0])
    ax00.set_title("Adjacency Matrix")
    ax01 = f.add_subplot(gs00[i][1])
    ax01.set_title("Local PageRank Matrix")
    ax00.set_xlabel("Node ID")
    ax00.set_ylabel("Node ID")
    ax01.set_xlabel("Node ID")
    ax01.set_ylabel("Node ID", rotation=-90, labelpad=15)
    ax00.spy(A_mat, cmap="PuBu")
    ax01.imshow(np.log(list2matrix(L, True) + 1), cmap="PuBu")
    ax01.yaxis.set_label_position("right")
    ax01.yaxis.tick_right()

# %% [markdown]
# ## Speedups
# A good speedup can be obtained by using a specialized data structure in order to store the adjacency matrix during the local PageRank™ computation. In particular, we used a list of lists representation.
# Such representation can get even better performances if one assumes unweighted networks, since it allows the computation of the nodes degree in $O(1)$ time.<br>
# Moreover, to further improve performances, <i>C</i> libraries were used within <i>Python</i> code. This allowed us to get results about twenty times faster than by using native <i>Python</i> ones.

# %% [markdown]
# ## Scalability
# As mentioned above, scalability is really important for PageRank™ algorithms, which have to be used often in quite large network.<br>
# Thus, in order to test the scalability properties of our implementation of the PageRank™ algorithm, presented above, we ran it on eleven different datasets, with an increasing number of nodes, and computed the time that it took to compute the  scores on each node. For a more complete analysis, the algorithm was also tested on two different processors.
# This process also allowed us to test if the complexity bound that was handed out in the reference paper is verified.<br>
# <br>
# As it can be seen from the figure below, the complexity can be correctly approximated with the estimate reported in the paper, i.e. $O(n \log n)$, even if there were some oscillations in the empirical values, which could be due to reasons which are not correlated to the algorithm itself.
#
# To verify the expected time complexity order, we used the following datasets from [[3](https://snap.stanford.edu/data/)]:
# 1. [wiki-Vote](https://snap.stanford.edu/data/wiki-Vote.html)
# 2. [p2p-Gnutella31](https://snap.stanford.edu/data/p2p-Gnutella31.html)
# 3. [ca-HepPh](https://snap.stanford.edu/data/ca-HepPh.html)
# 4. [email-EuAll](https://snap.stanford.edu/data/email-EuAll.html)
# 5. [email-Enron](https://snap.stanford.edu/data/email-Enron.html)
# 6. [com-DBLP](https://snap.stanford.edu/data/com-DBLP.html)
# 7. [ego-Facebook](https://snap.stanford.edu/data/ego-Facebook.html)

# %%
# load iMac's precomputed times (Intel Processor)
with np.load("data/precomputed_times/iMac.npz") as data:
    Ns=data["Ns"]
    avgDegs=data["avgDegs"]
    imac_weighted_avgs=data["weighted_avgs"]
    imac_weighted_stds=data["weighted_stds"]
    imac_unweighted_avgs=data["unweighted_avgs"]
    imac_unweighted_stds=data["unweighted_stds"]

# load Linux's precomputed times (AMD Processor)
# allow_pickle is forced to true due to windows compatibility
with np.load("data/precomputed_times/linux-tom.npz", allow_pickle=True) as data:
    linux_unweighted_avgs = np.array([time.average for time in data["arr_0"]])
    linux_unweighted_stds = np.array([time.stdev for time in data["arr_0"]])
    linux_weighted_avgs = np.array([time.average for time in data["arr_1"]])
    linux_weighted_stds = np.array([time.stdev for time in data["arr_1"]])

# define the NlogN function, weighted by constant c
# i.e. the definition of O(NlogN)
def fitFunc(x, c):
    return c*x*np.log(x)

# plot the curves and the corresponding fit
fig, axs = plt.subplots(1, 1, figsize=(15, 7))
im_w_set = axs.errorbar(Ns, imac_weighted_avgs, imac_weighted_stds, fmt='.')
im_uw_set = axs.errorbar(Ns, imac_unweighted_avgs, imac_unweighted_stds, fmt='x')
li_w_set = axs.errorbar(Ns, linux_weighted_avgs, linux_weighted_stds, fmt='.')
li_uw_set = axs.errorbar(Ns, linux_unweighted_avgs, linux_unweighted_stds, fmt='x')
axs.set_xscale("log")
axs.set_yscale("log")
axs.set_title("Execution Time on Single Core")
axs.legend(["Intel on iMac, Weighted Algorithm",
            "Intel on iMac, Unweighted Algorithm",
            "AMD on Linux, Weighted Algorithm",
            "AMD on Linux, Unweighted Algorithm"])

axs.plot(Ns, fitFunc(Ns, 2e-5), color=im_w_set.lines[0].get_color())
axs.plot(Ns, fitFunc(Ns, 1.9e-5), color=im_uw_set.lines[0].get_color())
axs.plot(Ns, fitFunc(Ns, 5e-5), color=li_w_set.lines[0].get_color())
axs.plot(Ns, fitFunc(Ns, 1e-5), color=li_uw_set.lines[0].get_color())

axs.set_xlabel("Number of nodes, $N$")
axs.set_ylabel("Execution Time, $t$ [s]")
axs.grid(True, which="both")

# %% [markdown]
# ## Clustering
#
# Clustering is the unsupervised learning task of grouping a set of objects in such a way that objects that present similar characteristics, based on a certain metric, belong to the same group. Algorithms that solve this task can be very different between each other: different metrics can be used to evaluate the similarity between nodes, and several approaches can be chosen to decide how the grouping actually happens.<br>
# In this context, the intrinsic metric used by each algorithm was obtained by exploiting the PageRank™ score assigned to each of the nodes in the network. To highlight how the same metric can lead to different results, we decided to implement four different clustering algorithms exploiting different approaches.<br>
# <br>
# The first proposed algorithm is based on the idea of flooding the clusters to nodes which comply to a certain hierarchical criteria. In particular starting from centroids the algorithm moves to the neighbours with highest Local PageRank™ score (namely the matrix $L$) assigning them to the cluster centered in that centroid.<br>
# To do so, we decided to use as data structure a list containing $K$ queues, one for each centroid. Each queue contains the nodes that have to be expanded, ranked on the base of the number of expansions they have left, which is a measure computed using the PageRank™ value of the node itself. The expansion is centered in the centroid, which at the beginning is the only node in the queue: by itereating the process, it will subsequently contain the cluster boundary. <br>
# This algorithm is heavily dependent on the choice of the centroids: if they are placed in the edge of the cluster, the number of expansions might not be sufficient to flood to all the cluster before other clusters expand to it.<br>
# Like in most clustering algorithms, the choice of the centroids impact heavily the grouping of the nodes. In this project we decided to use the centroids provided by the datasets, but alternatively, it would be possible to choose the centroids based global PageRank™ value heuristics.<br>
# <br>
# The second proposed algorithm is heavily based on the first one, proposed above, but here just one pririty queue has been used, which contains, as before, initially just the centroids. After each operation, the element with highest score is popped, it is assigned to a cluster, and its neighbours are added to the queue. When added to the queue, the node keeps the information regarding the cluster to which the father belongs.<br>
# By comparing the results of this version with the one presented above, it is clear that the division between the clusters is more defined and coherent with the graphical representation, with only few nodes lying outside of it, so the issue due to the centroid's position with respect to the cluster has been mitigated.<br>
# These first two clustering algorithms are parametric, i.e. they require as input information regarding the number of clusters and their centroids. Conversely, the following two do not require any a priori data.<br>
# <br>
# The third algorithm is based on the idea of walking through the network until you reach a local relevance maxima. Following this criteria, each node found in the path is added to the same cluster. If the encountered node during a general path was already assigned to a pre-existing cluster, the path stops there and all the visited nodes are added to this latter cluster.<br>
# Thanks to this last rule, very close clusters are joined together in a bigger one. <br>
# This, however, does not fully work since, as it can be seen from the results below, there are still small clusters within the bigger one that are kept separated from it.<br> This algorithm runs in almost linear time, as each node is visited just once: only very few nodes are visited at most twice.<br>
# <br>
# The last algorithm uses the average degree of its neighbours, where the degree is computed on the weighted network generated by the PageRank™ algorithm. As a criteria to group the clusters together, we look at the variability of the separeted cluster and, if the score increases when grouping one or more clusters together, we merge them into one, otherwise, we keep them reparate. Specifically, the algorithm starts by computing the in-degree for each of the neighbours of the node, then takes the average and, by default, puts every node in a different cluster. Then, iteratively, the algorithm merges these clusters computing their variability, which is based on the standard deviation.<br>
# <br>
# All datasets were taken from [[4](http://cs.joensuu.fi/sipu/datasets)].

# %%
# initialize the algorithm names list
algorithm_names = ["cluster1", "cluster2", "cluster3", "cluster4"]

# initialize the clusters dictionary
computed_clusters = {algorithm_name: {} for algorithm_name in algorithm_names}

# and compute them
for name in names:
    
    # randomly initialize the centroids, for the algorithms that need them
    centroids = []
    clusters = datasets[name]["clusters"]
    # fix the seed for reproducibilty
    np.random.seed(0)
    # compute the centroids
    for cluster in np.unique(clusters):
        nodes = np.arange(datasets[name]["A_mat"].shape[0])[clusters==cluster]
        centroids.append(np.random.choice(nodes, 1)[0])
        
    # store network data
    computed_clusters[algorithm_names[0]][name] = cluster1(datasets[name]["L"], np.array(centroids), 20) # TODO: correct
    computed_clusters[algorithm_names[1]][name] = cluster2(datasets[name]["L"], np.array(centroids)) # TODO: correct
    computed_clusters[algorithm_names[2]][name] = cluster3(datasets[name]["L_T"]) # TODO: correct
    computed_clusters[algorithm_names[3]][name] = cluster4(datasets[name]["L_T"]) # TODO: correct

# %%
# create the figure for the plot
f = plt.figure(figsize=(14, 21))

# create major subplots
gs0 = gridspec.GridSpec(4, 1, figure=f, hspace=.25)

# further split the second row
gs00 = [gridspec.GridSpecFromSubplotSpec(1, 3, subplot_spec=gs, wspace=0.05) for gs in gs0]

# iterate over the results and plt them
for i, algorithm_name in enumerate(algorithm_names):
    ax0 = f.add_subplot(gs0[i])
    ax0.set_title("Algorithm: " + algorithm_name, pad=30, fontweight="bold")
    ax0.axis("off")

    # perform the clustering and plot results
    for j, name in enumerate(names):
        ax00 = f.add_subplot(gs00[i][j])
        ax00.set_title("Network: " + name)
        ax00.axis("off")
        plotNetworkClusters(
            datasets[name]["A_mat"],
            list(computed_clusters[algorithm_name][name]),
            node_size=10,
            draw_edges=True,
            alpha=0.1,
            pos=datasets[name]["positions"],
            cbar=False,
            ax=ax00
        )

# %% [markdown]
# ## Bibliography
# 1. [Andersen, Chung, Lang. 2006. Local graph partitioning using pagerank vectors.](http://www.leonidzhukov.net/hse/2015/networks/papers/andersen06localgraph.pdf)
# 2. [Gopal Pandurangan, Peter Robinson, and Michele Scquizzato. 2018. On the Distributed Complexity of Large-Scale Graph Computations. In Proceedings of the 30th on Symposium on Parallelism in Algorithms and Architectures (SPAA ’18). Association for Computing Machinery, New York, NY, USA, 405–414.](https://dl.acm.org/doi/pdf/10.1145/3210377.3210409?download=true)
# 3. [Jure Leskovec and Andrej Krevl. June, 2014. SNAP Datasets: Stanford Large Network Dataset Collection.](https://snap.stanford.edu/data)
# 4. [P. Fränti and S. Sieranoja. December, 2018. K-means properties on six clustering benchmark datasets Applied Intelligence, 48 (12), 4743-4759](http://cs.joensuu.fi/sipu/datasets)
